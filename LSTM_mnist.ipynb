# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import models, layers

# Load MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values
x_train = x_train / 255.0
x_test = x_test / 255.0

# Convert labels to one-hot vectors
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# LSTM model treating each image row as a timestep
model = models.Sequential([
    layers.LSTM(64, input_shape=(28, 28), activation='tanh'),
    layers.Dense(32, activation='relu'),      # Optional hidden layer
    layers.Dense(10, activation='softmax')    # Output layer for 10 classes
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    x_train, y_train,
    epochs=5,
    batch_size=128,
    validation_data=(x_test, y_test)
)

# Evaluate the model
loss, acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 45ms/step - accuracy: 0.5859 - loss: 1.2271 - val_accuracy: 0.9118 - val_loss: 0.2767
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 39ms/step - accuracy: 0.9306 - loss: 0.2277 - val_accuracy: 0.9452 - val_loss: 0.1809
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 42ms/step - accuracy: 0.9569 - loss: 0.1415 - val_accuracy: 0.9670 - val_loss: 0.1070
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 39ms/step - accuracy: 0.9665 - loss: 0.1099 - val_accuracy: 0.9659 - val_loss: 0.1098
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 42ms/step - accuracy: 0.9740 - loss: 0.0863 - val_accuracy: 0.9734 - val_loss: 0.0857
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9684 - loss: 0.1013
# Test Accuracy: 0.9734
